# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./PlayGolfData.csv")

# %%
df
# Out:
#     Unnamed: 0   Date Weekday Month Temperature Humidity Wind   Outlook  \
# 0            0  03-25     Mon   Mar        High      Dry   No     sunny
# 1            1  03-26     Tue   Mar         Low    Humid  Yes     rainy
# 2            2  03-27     Wed   Mar        High      Dry  Yes  overcast
# 3            3  03-28     Thu   Mar     Extreme      Dry  Yes     sunny
# 4            4  03-29     Fri   Mar         Low    Humid   No     rainy
# 5            5  03-30     Sat   Mar        High    Humid   No  overcast
# 6            6  03-31     Sun   Mar        High      Dry  Yes     sunny
# 7            7  04-01     Mon   Apr         Low    Humid   No     rainy
# 8            8  04-02     Tue   Apr        High      Dry  Yes     sunny
# 9            9  04-03     Wed   Apr     Extreme      Dry  Yes  overcast
# 10          10  04-04     Thu   Apr        High    Humid   No     sunny
# 11          11  04-05     Fri   Apr         Low      Dry  Yes     rainy
#
#     Crowdedness
# ...

# %%
df["Weekday_label"] = pd.
